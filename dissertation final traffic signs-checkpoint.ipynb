# %%
# import libraries 
import pickle

import pandas as pd # Import Pandas for data manipulation using dataframes
import numpy as np # Import Numpy for data statistical analysis 
import matplotlib.pyplot as plt # Import matplotlib for data visualisation
import random

# %%
with open("./traffic-signs-data/train.p", mode='rb') as training_data:
    train = pickle.load(training_data)#reading the data

# %%
with open("./traffic-signs-data/valid.p", mode='rb') as validation_data:
    valid = pickle.load(validation_data)

# %%
with open("./traffic-signs-data/test.p", mode='rb') as testing_data:
    test = pickle.load(testing_data)

# %%
X_train, y_train = train['features'], train['labels']
X_validation, y_validation = valid['features'], valid['labels']
X_test, y_test = test['features'], test['labels']

# %%
X_train.shape#shape of dataset
# Out:
# (34799, 32, 32, 3)

# %%
y_train.shape
# Out:
# (34799,)

# %%
i = 100
plt.imshow(X_train[i]) # Show images are not shuffled
y_train[i]
# Out:
# 41

# %%
## Shuffle the dataset 
from sklearn.utils import shuffle
X_train, y_train = shuffle(X_train, y_train)

# %%
X_train_gray = np.sum(X_train/3, axis=3, keepdims=True)
X_test_gray  = np.sum(X_test/3, axis=3, keepdims=True)
X_validation_gray  = np.sum(X_validation/3, axis=3, keepdims=True)

# %%
X_train_gray_norm = (X_train_gray - 128)/128 
X_test_gray_norm = (X_test_gray - 128)/128
X_validation_gray_norm = (X_validation_gray - 128)/128

# %%
X_train_gray.shape
# Out:
# (34799, 32, 32, 1)

# %%
i = 700
plt.imshow(X_train_gray[i].squeeze(), cmap='gray')
plt.figure()
plt.imshow(X_train[i])

# %%
#importing train_test_split from scikit library
#importing Keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import TensorBoard

# from subprocess import check_output
from sklearn.model_selection import train_test_split

# %%
image_shape = X_train_gray[i].shape

# %%
cnn_model = Sequential()
cnn_model.add(Conv2D(32,3, 3, input_shape = image_shape, activation='relu'))
cnn_model.add(MaxPooling2D(pool_size = (2, 2)))
cnn_model.add(Flatten())
cnn_model.add(Dense(32, activation = 'relu'))
cnn_model.add(Dense(43, activation = 'sigmoid'))

# %%
cnn_model.compile(loss ='sparse_categorical_crossentropy', optimizer=Adam(lr=0.001),metrics =['accuracy'])
# Out:
# C:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
history = cnn_model.fit(X_train_gray_norm,
                        y_train,
                        batch_size=500,
                        epochs=50,
                        verbose=1,
                        validation_data = (X_validation_gray_norm,y_validation))
# Out:
# Epoch 1/50
# 70/70 [==============================] - 3s 26ms/step - loss: 3.4542 - accuracy: 0.1089 - val_loss: 3.3795 - val_accuracy: 0.1503
# Epoch 2/50
# 70/70 [==============================] - 2s 31ms/step - loss: 2.8606 - accuracy: 0.2736 - val_loss: 2.8121 - val_accuracy: 0.2941
# Epoch 3/50
# 70/70 [==============================] - 1s 21ms/step - loss: 2.2686 - accuracy: 0.4057 - val_loss: 2.3933 - val_accuracy: 0.3497
# Epoch 4/50
# 70/70 [==============================] - 2s 22ms/step - loss: 1.8714 - accuracy: 0.5011 - val_loss: 2.0937 - val_accuracy: 0.4261
# Epoch 5/50
# 70/70 [==============================] - 1s 21ms/step - loss: 1.6069 - accuracy: 0.5670 - val_loss: 1.8915 - val_accuracy: 0.4800
# Epoch 6/50
# 70/70 [==============================] - 2s 25ms/step - loss: 1.4191 - accuracy: 0.6136 - val_loss: 1.7417 - val_accuracy: 0.5408
# Epoch 7/50
# 70/70 [==============================] - 2s 24ms/step - loss: 1.2785 - accuracy: 0.6476 - val_loss: 1.6059 - val_accuracy: 0.5664
# Epoch 8/50
# 70/70 [==============================] - 2s 34ms/step - loss: 1.1649 - accuracy: 0.6794 - val_loss: 1.5333 - val_accuracy: 0.5803
# Epoch 9/50
# 70/70 [==============================] - 2s 33ms/step - loss: 1.0843 - accuracy: 0.6999 - val_loss: 1.4730 - val_accuracy: 0.6011
# Epoch 10/50
# 70/70 [==============================] - 2s 35ms/step - loss: 1.0128 - accuracy: 0.7178 - val_loss: 1.4276 - val_accuracy: 0.6029
# Epoch 11/50
# 70/70 [==============================] - 2s 27ms/step - loss: 0.9531 - accuracy: 0.7317 - val_loss: 1.3567 - val_accuracy: 0.6345
# Epoch 12/50
# 70/70 [==============================] - 2s 24ms/step - loss: 0.8933 - accuracy: 0.7541 - val_loss: 1.3076 - val_accuracy: 0.6404
# Epoch 13/50
# 70/70 [==============================] - 2s 36ms/step - loss: 0.8538 - accuracy: 0.7622 - val_loss: 1.2782 - val_accuracy: 0.6594
# Epoch 14/50
# 70/70 [==============================] - 2s 30ms/step - loss: 0.8127 - accuracy: 0.7715 - val_loss: 1.2344 - val_accuracy: 0.6662
# Epoch 15/50
# 70/70 [==============================] - 3s 41ms/step - loss: 0.7830 - accuracy: 0.7817 - val_loss: 1.2370 - val_accuracy: 0.6469
# Epoch 16/50
# 70/70 [==============================] - 3s 44ms/step - loss: 0.7469 - accuracy: 0.7917 - val_loss: 1.1879 - val_accuracy: 0.6800
# Epoch 17/50
# 70/70 [==============================] - 3s 40ms/step - loss: 0.7198 - accuracy: 0.8006 - val_loss: 1.1827 - val_accuracy: 0.6880
# Epoch 18/50
# 70/70 [==============================] - 3s 37ms/step - loss: 0.6989 - accuracy: 0.8046 - val_loss: 1.1871 - val_accuracy: 0.6984
# Epoch 19/50
# 70/70 [==============================] - 2s 26ms/step - loss: 0.6732 - accuracy: 0.8138 - val_loss: 1.1627 - val_accuracy: 0.6907
# Epoch 20/50
# 70/70 [==============================] - 2s 25ms/step - loss: 0.6463 - accuracy: 0.8210 - val_loss: 1.1213 - val_accuracy: 0.7095
# Epoch 21/50
# 70/70 [==============================] - 2s 23ms/step - loss: 0.6376 - accuracy: 0.8196 - val_loss: 1.1304 - val_accuracy: 0.7057
# Epoch 22/50
# 70/70 [==============================] - 1s 20ms/step - loss: 0.6101 - accuracy: 0.8316 - val_loss: 1.0823 - val_accuracy: 0.7141
# Epoch 23/50
# 70/70 [==============================] - 1s 20ms/step - loss: 0.5957 - accuracy: 0.8351 - val_loss: 1.0891 - val_accuracy: 0.7070
# Epoch 24/50
# 70/70 [==============================] - 1s 19ms/step - loss: 0.5781 - accuracy: 0.8388 - val_loss: 1.0823 - val_accuracy: 0.7186
# Epoch 25/50
# 70/70 [==============================] - 1s 19ms/step - loss: 0.5622 - accuracy: 0.8443 - val_loss: 1.0608 - val_accuracy: 0.7374
# Epoch 26/50
# 70/70 [==============================] - 1s 20ms/step - loss: 0.5489 - accuracy: 0.8494 - val_loss: 1.0655 - val_accuracy: 0.7361
# Epoch 27/50
# 70/70 [==============================] - 1s 20ms/step - loss: 0.5373 - accuracy: 0.8525 - val_loss: 1.0806 - val_accuracy: 0.7070
# Epoch 28/50
# 70/70 [==============================] - 1s 20ms/step - loss: 0.5188 - accuracy: 0.8587 - val_loss: 1.0355 - val_accuracy: 0.7379
# Epoch 29/50
# 70/70 [==============================] - 2s 22ms/step - loss: 0.5145 - accuracy: 0.8559 - val_loss: 1.0595 - val_accuracy: 0.7297
# Epoch 30/50
# 70/70 [==============================] - 1s 20ms/step - loss: 0.5012 - accuracy: 0.8613 - val_loss: 1.0537 - val_accuracy: 0.7279
# Epoch 31/50
# 70/70 [==============================] - 1s 21ms/step - loss: 0.4882 - accuracy: 0.8650 - val_loss: 1.0369 - val_accuracy: 0.7415
# Epoch 32/50
# 70/70 [==============================] - 1s 20ms/step - loss: 0.4781 - accuracy: 0.8682 - val_loss: 1.0332 - val_accuracy: 0.7429
# Epoch 33/50
# 70/70 [==============================] - 1s 20ms/step - loss: 0.4662 - accuracy: 0.8735 - val_loss: 1.0175 - val_accuracy: 0.7458
# Epoch 34/50
# 70/70 [==============================] - 2s 23ms/step - loss: 0.4601 - accuracy: 0.8745 - val_loss: 1.0372 - val_accuracy: 0.7336
# Epoch 35/50
# 70/70 [==============================] - 1s 20ms/step - loss: 0.4519 - accuracy: 0.8763 - val_loss: 1.0043 - val_accuracy: 0.7580
# Epoch 36/50
# 70/70 [==============================] - 2s 23ms/step - loss: 0.4401 - accuracy: 0.8826 - val_loss: 1.0231 - val_accuracy: 0.7422
# Epoch 37/50
# 70/70 [==============================] - 1s 21ms/step - loss: 0.4318 - accuracy: 0.8840 - val_loss: 1.0394 - val_accuracy: 0.7345
# Epoch 38/50
# 70/70 [==============================] - 1s 20ms/step - loss: 0.4285 - accuracy: 0.8827 - val_loss: 1.0274 - val_accuracy: 0.7447
# Epoch 39/50
# 70/70 [==============================] - 1s 19ms/step - loss: 0.4208 - accuracy: 0.8842 - val_loss: 1.0196 - val_accuracy: 0.7440
# Epoch 40/50
# 70/70 [==============================] - 2s 28ms/step - loss: 0.4092 - accuracy: 0.8906 - val_loss: 1.0229 - val_accuracy: 0.7633
# Epoch 41/50
# 70/70 [==============================] - 2s 23ms/step - loss: 0.4038 - accuracy: 0.8912 - val_loss: 1.0142 - val_accuracy: 0.7519
# Epoch 42/50
# 70/70 [==============================] - 2s 23ms/step - loss: 0.3984 - accuracy: 0.8934 - val_loss: 0.9894 - val_accuracy: 0.7546
# Epoch 43/50
# 70/70 [==============================] - 2s 28ms/step - loss: 0.3895 - accuracy: 0.8945 - val_loss: 0.9869 - val_accuracy: 0.7578
# Epoch 44/50
# 70/70 [==============================] - 2s 24ms/step - loss: 0.3818 - accuracy: 0.8986 - val_loss: 0.9926 - val_accuracy: 0.7669
# Epoch 45/50
# 70/70 [==============================] - 2s 23ms/step - loss: 0.3805 - accuracy: 0.8976 - val_loss: 0.9940 - val_accuracy: 0.7680
# Epoch 46/50
# 70/70 [==============================] - 2s 22ms/step - loss: 0.3733 - accuracy: 0.8982 - val_loss: 0.9638 - val_accuracy: 0.7805
# Epoch 47/50
# 70/70 [==============================] - 2s 22ms/step - loss: 0.3639 - accuracy: 0.9038 - val_loss: 1.0131 - val_accuracy: 0.7587
# Epoch 48/50
# 70/70 [==============================] - 1s 21ms/step - loss: 0.3603 - accuracy: 0.9044 - val_loss: 1.0199 - val_accuracy: 0.7531
# Epoch 49/50
# 70/70 [==============================] - 2s 23ms/step - loss: 0.3548 - accuracy: 0.9049 - val_loss: 1.0026 - val_accuracy: 0.7635
# Epoch 50/50
# 70/70 [==============================] - 2s 24ms/step - loss: 0.3451 - accuracy: 0.9100 - val_loss: 0.9768 - val_accuracy: 0.7746

# %%
score = cnn_model.evaluate(X_test_gray_norm, y_test,verbose=0)
print('Test Accuracy : {:.4f}'.format(score[1]))
# Out:
# Test Accuracy : 0.7440

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(len(accuracy))
plt.plot(epochs, accuracy, 'bo', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
predict_x = cnn_model.predict(X_test_gray_norm)
predicted_classes = np.argmax(predict_x, axis=1)

#get the indices to be plotted
y_true = y_test
# Out:
# 395/395 [==============================] - 1s 2ms/step

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_true, predicted_classes)
cm
# Out:
# array([[ 20,  16,   3, ...,   0,   0,   0],
#        [137, 482,  40, ...,   3,   0,   0],
#        [114, 116, 397, ...,   5,   0,   0],
#        ...,
#        [  6,   3,   6, ...,  26,   0,   0],
#        [  0,   0,   0, ...,   0,  12,   1],
#        [  0,   2,   0, ...,   0,   3,  47]], dtype=int64)

# %%
for i in range(0,12):
    plt.subplot(4,3,i+1)
    plt.imshow(X_test_gray_norm[i+10].squeeze(), cmap='gray', interpolation='none')
    plt.title("Predicted {}, Class {}".format(predicted_classes[i+10], y_true[i+10]))
    plt.tight_layout()
